# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

sub1 = pd.read_csv('/content/drive/MyDrive/주피터_대피소/kaggle&github/Kaggle/참가중대회/otto~jan31,2023/submission1.csv')
sub2 = pd.read_csv('/content/drive/MyDrive/주피터_대피소/kaggle&github/Kaggle/참가중대회/otto~jan31,2023/submission2.csv')
sub3 = pd.read_csv('/content/drive/MyDrive/주피터_대피소/kaggle&github/Kaggle/참가중대회/otto~jan31,2023/submission3.csv')

# %%
final_sub = pd.concat([sub1,sub2,sub3], axis=0)

# %%
final_sub = final_sub.to_csv('/content/drive/MyDrive/주피터_대피소/kaggle&github/Kaggle/참가중대회/otto~jan31,2023/submission.csv', index=False)

# %%
final_sub
